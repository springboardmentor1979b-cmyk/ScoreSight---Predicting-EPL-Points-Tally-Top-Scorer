# %%
import joblib
import pandas as pd

rf_model = joblib.load("rf_regression_model.pkl")
gb_model = joblib.load("gb_classification_model.pkl")

# %%
df = pd.read_csv("../Week-4_Feature_Scaling/minmax_scaled_epl.csv")
sample = df.sample(5)
sample
# Out:
#                Name  Jersey Number Nationality   Age  Appearances  Wins  \
# 355  Chris Smalling           12.0     England  30.0     0.405204   122
# 368            Fred           17.0      Brazil  27.0     0.083643    22
# 88   Aaron Connolly            7.0     Ireland  20.0     0.046468     8
# 564         Vitinha           20.0    Portugal  20.0     0.000000     1
# 163  James McCarthy           22.0     Ireland  29.0     0.477695    87
#
#      Losses     Goals  Goals per match  Headed goals  ...  Catches  \
# 355      56  0.061453              NaN           8.0  ...      NaN
# 368      14  0.000000             0.02           0.0  ...      NaN
# 88       12  0.016760             0.15           0.0  ...      NaN
# 564       0  0.068149             1.00           0.0  ...      NaN
# 163     102  0.067039             0.05           0.0  ...      NaN
#
#      Sweeper clearances  Throw outs  Goal Kicks  Yellow cards  Red cards  \
# ...

# %%
sample['Predicted_Goals'] = rf_model.predict(
    sample[['Appearances', 'Shots', 'Passes', 'Assists']]
)

sample['Predicted_Result'] = gb_model.predict(
    sample[['Shots', 'Passes', 'Assists']]
)

sample
# Out:
#                Name  Jersey Number Nationality   Age  Appearances  Wins  \
# 355  Chris Smalling           12.0     England  30.0     0.405204   122
# 368            Fred           17.0      Brazil  27.0     0.083643    22
# 88   Aaron Connolly            7.0     Ireland  20.0     0.046468     8
# 564         Vitinha           20.0    Portugal  20.0     0.000000     1
# 163  James McCarthy           22.0     Ireland  29.0     0.477695    87
#
#      Losses     Goals  Goals per match  Headed goals  ...  Throw outs  \
# 355      56  0.061453              NaN           8.0  ...         NaN
# 368      14  0.000000             0.02           0.0  ...         NaN
# 88       12  0.016760             0.15           0.0  ...         NaN
# 564       0  0.068149             1.00           0.0  ...         NaN
# 163     102  0.067039             0.05           0.0  ...         NaN
#
#      Goal Kicks  Yellow cards  Red cards  Fouls  Offsides Club_encoded  \
# ...
